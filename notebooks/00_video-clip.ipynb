# %%
# from video import clip_and_merge

# %%
# 使用例（複数区間を指定）
input_mp4 = "/home/work/assets/20250308_140538.mp4"
output_mp4 = "merged_output.mp4"

intervals = [
    ("01:11:40", "01:11:53"),  # 1つ目の区間（HH:MM:SS形式または秒数指定）
]

# %%
clip_and_merge(input_mp4, intervals, output_mp4)
# Out:
# Moviepy - Building video merged_output.mp4.
# MoviePy - Writing audio in merged_outputTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video merged_output.mp4
# t:  33%|███▎      | 130/389 [00:01<00:02, 96.19it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready merged_output.mp4
