# %%
from youtube import download_youtube_mp4

# %%
url = "https://www.youtube.com/watch?v=5WFmSJyyCAM&ab_channel=%E3%83%86%E3%83%AC%E6%9D%B1%E5%8D%93%E7%90%83%E3%83%81%E3%83%A3%E3%83%B3%E3%83%8D%E3%83%AB"

# %%
download_youtube_mp4(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 download_youtube_mp4(url)
#
# File ~/src/youtube.py:20, in download_youtube_mp4(url, output_path)
#      17 yt = YouTube(url)
#      19 # 動画の中で最も画質の良いmp4フォーマットを選択
# ---> 20 stream = yt.streams.filter(file_extension='mp4', progressive=True).order_by('resolution').desc().first()
#      22 if stream is None:
#      23     raise ValueError("利用可能なMP4形式の動画が見つかりませんでした。")
#
# File ~/.cache/pypoetry/virtualenvs/work-3UyvmeC2-py3.11/lib/python3.11/site-packages/pytube/__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# ...

# %%
input_mp4 = "/home/work/assets/20250308_140538.mp4"
output_mp4 = "/home/work/assets/20250308_140538-right-half.mp4"

# %%
extract_right_half(input_mp4, output_mp4)
